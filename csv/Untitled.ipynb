# %%
import pandas as pd

client_file = pd.read_csv('clients.csv')

client_file['date_inscription'] = pd.to_datetime(client_file.date_inscription)

display(client_file.head(10))

columns_to_keep = ['CUSTUMER_ID', 'date_inscription']

client_file = client_file[columns_to_keep]

client_file.to_csv('clients_treated.csv', index=False)
# Out:
# /tmp/ipykernel_104582/2285535831.py:5: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   client_file['date_inscription'] = pd.to_datetime(client_file.date_inscription)
#          CUSTUMER_ID date_inscription
# 0  CUST-2KYXXXW1NK7I       2023-07-17
# 1  CUST-NR43XRT2PXYG       2023-09-07
# 2  CUST-CH58P8PSVIYU       2021-08-24
# 3  CUST-CI7JQHW4TIYT       2021-12-22
# 4  CUST-3QHP3KL4NPP2       2020-12-20
# 5  CUST-24HVQPZX5YLL       2021-08-26
# 6  CUST-FTWLEOUVAAPD       2024-08-06
# 7  CUST-TA459CNFKWS7       2023-06-15
# 8  CUST-BBCH81JAM8HT       2023-08-12
# 9  CUST-IH6Q0NM4GJ76       2020-07-10
